# %%
number=[1,4,6,7]
print(number[0])
# Out:
# 1

# %%
print(number[3:])
# Out:
# [7]

# %%
a=8
b=a
a+=1
print(a)
# Out:
# 9

# %%
from collections import defaultdict

["1-guruh"]=="Dilnovoz", "Aziz","Siroj"
guruhlar = defaultdict(list)
guruhlar["1-guruh"].append("Ali")   # kalit mavjud bo'lmasa ham xato bermaydi
guruhlar["1-guruh"].append("Vali")
print(guruhlar)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 from collections import defaultdict
#       2
# ----> 3 1-guruh=="Dilnovoz", "Aziz","Siroj"
#       4 guruhlar = defaultdict(list)
#       5 guruhlar["1-guruh"].append("Ali")   # kalit mavjud bo'lmasa ham xato bermaydi
#       6 guruhlar["1-guruh"].append("Vali")
#
# NameError: name 'guruh' is not defined
